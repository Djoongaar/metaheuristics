# %%
import plotly
import pandas as pd

# %%
# Поколение 0
import json

def get_data(x, ind=0):
    x = x.replace("'", '"').replace("None", "null")
    return json.loads(f'{x}')[ind]


df = pd.read_csv('log/baboon_logo_firefly.csv', header=None)
for i in range(10):
    df[i+2] = df[1].map(lambda x: get_data(x, ind=i))

df
# Out:
#      0                                                  1   \
# 0     0  [{'value': 17.781730100563447, 'score': 2.4028...
# 1     0  [{'value': 17.781730100563447, 'score': 2.4058...
# 2     0  [{'value': 14.860215045782901, 'score': 2.4049...
# 3     0  [{'value': 11.593515537569944, 'score': 2.3993...
# 4     0  [{'value': 11.593515537569944, 'score': 2.3944...
# ..   ..                                                ...
# 995   9  [{'value': 9.281309202269568, 'score': 2.39195...
# 996   9  [{'value': 9.281309202269568, 'score': 2.39195...
# 997   9  [{'value': 9.281309202269568, 'score': 2.39195...
# 998   9  [{'value': 9.281309202269568, 'score': 2.39195...
# 999   9  [{'value': 9.281309202269568, 'score': 2.39195...
#
#                                                     2   \
# 0    {'value': 17.781730100563447, 'score': 2.40282...
# 1    {'value': 17.781730100563447, 'score': 2.40586...
# 2    {'value': 14.860215045782901, 'score': 2.40496...
# ...
